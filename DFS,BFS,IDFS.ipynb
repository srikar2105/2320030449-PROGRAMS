# %%
#Program for breadth first search

from collections import defaultdict

class Graph:
    def __init__(self):
        self.graph = defaultdict(list)

    def add_edge(self, u, v):
        self.graph[u].append(v)

    def bfs(self, start_node):
        visited = [False] * (len(self.graph))
        queue = []
        visited[start_node] = True
        queue.append(start_node)

        while queue:
          s = queue.pop(0)
          print(s, end=" ")

          for i in self.graph[s]:
            if visited[i] == False:
              visited[i] = True
              queue.append(i)

g = Graph()
g.add_edge(0, 1)
g.add_edge(0, 2)
g.add_edge(1, 2)
g.add_edge(2, 0)
g.add_edge(2, 3)
g.add_edge(3, 3)

print("Breadth First Search")
g.bfs(2)
# Out:
# Breadth First Search
# 2 0 3 1

# %%
#Program for depth first search

from collections import defaultdict

class Graph:
    def __init__(self):
        self.graph = defaultdict(list)

    def add_edge(self, u, v):
        self.graph[u].append(v)

    def dfs_util(self, v, visited):
        visited[v] = True
        print(v, end=" ")

        for neighbour in self.graph[v]:
            if visited[neighbour] == False:
                self.dfs_util(neighbour, visited)

    def dfs(self, start_node):
        num_vertices = len(self.graph)
        visited = [False] * num_vertices
        self.dfs_util(start_node, visited)

g = Graph()
g.add_edge(0, 1)
g.add_edge(0, 2)
g.add_edge(1, 2)
g.add_edge(2, 0)
g.add_edge(2, 3)
g.add_edge(3, 3)

print("\nDepth First Search")
g.dfs(2)
# Out:
# Depth First Search
# 2 0 1 3

# %%
class Graph:
    def __init__(self, V):
        self.V = V
        self.adj = [[] for _ in range(V)]

    def addEdge(self, v, w):
        self.adj[v].append(w)

    def DLS(self, src, target, limit):
        if src == target:
            return True
        if limit <= 0:
            return False
        for i in self.adj[src]:
            if self.DLS(i, target, limit - 1):
                return True
        return False

    def IDDFS(self, src, target, max_depth):
        for limit in range(max_depth + 1):
            if self.DLS(src, target, limit):
                return True
        return False

V = 7
graph = Graph(V)
graph.addEdge(0, 1)
graph.addEdge(0, 2)
graph.addEdge(1, 3)
graph.addEdge(1, 4)
graph.addEdge(2, 5)
graph.addEdge(2, 6)

src = 0
target = 6
max_depth = 3
if graph.IDDFS(src, target, max_depth):
    print(f"Target {target} is reachable from source {src} within {max_depth} steps.")
else:
    print(f"Target {target} is not reachable from source {src} within {max_depth} steps.")
# Out:
# Target 6 is reachable from source 0 within 3 steps.
